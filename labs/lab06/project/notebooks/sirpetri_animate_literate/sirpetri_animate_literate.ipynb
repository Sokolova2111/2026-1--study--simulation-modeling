# %% [markdown]
# # Анимация динамики SIR (линия через состояния)
#
# Анимация показывает, как меняется численность групп S, I, R
# в виде линии, соединяющей точки (S, I, R) на каждом кадре.
# По оси X — группы, по оси Y — численность.
#
# На анимации видно:
# - На первых кадрах S = 990, I = 10, R = 0
# - Постепенно S падает, I растёт
# - В момент пика I достигает максимума, затем снижается
# - R растёт и выходит на плато
# - Волна инфекции проходит через популяцию

# %% [markdown]
# ## Подключение модулей

# %%
using DrWatson
@quickactivate "project"
include(srcdir("SIRPetri.jl"))
using .SIRPetri
using Plots

# %% [markdown]
# ## Параметры модели

# %%
β = 0.3      # Коэффициент заражения
γ = 0.1      # Коэффициент выздоровления
tmax = 100.0 # Время симуляции
# Out:
# 100.0

# %% [markdown]
# ## Создание сети Петри

# %%
net, u0, states = build_sir_network(β, γ)
# Out:
# (AlgebraicPetri.LabelledPetriNet:
#   T = 1:2
#   S = 1:3
#   I = 1:3
#   O = 1:3
#   Name = 1:0
#   it : I → T = [1, 1, 2]
#   is : I → S = [1, 2, 2]
#   ot : O → T = [1, 1, 2]
#   os : O → S = [2, 2, 3]
#   tname : T → Name = [:infection, :recovery]
#   sname : S → Name = [:S, :I, :R], [990.0, 10.0, 0.0], [:S, :I, :R])

# %% [markdown]
# ## Детерминированная симуляция

# %%
df = simulate_deterministic(net, u0, (0.0, tmax), saveat = 0.5, rates = [β, γ])
# Out:
# 201×4 DataFrame
#  Row │ time     S              I            R
#      │ Float64  Float64        Float64      Float64
# ─────┼───────────────────────────────────────────────
#    1 │     0.0  990.0           10.0          0.0
#    2 │     0.5    2.47053e-7   952.691       47.3086
#    3 │     1.0    3.28252e-7   906.228       93.7719
#    4 │     1.5   -1.78365e-7   862.031      137.969
#    5 │     2.0   -2.6597e-7    819.989      180.011
#    6 │     2.5    2.389e-7     779.998      220.002
#    7 │     3.0   -3.23518e-7   741.957      258.043
#    8 │     3.5   -2.30682e-7   705.771      294.229
#    9 │     4.0    3.04028e-8   671.35       328.65
#   10 │     4.5    3.63345e-8   638.608      361.392
#   11 │     5.0   -3.54734e-7   607.463      392.537
#   ⋮  │    ⋮           ⋮             ⋮          ⋮
#  192 │    95.5    2.1293e-12     0.0713092  999.929
#  193 │    96.0    2.10724e-12    0.0678325  999.932
#  194 │    96.5    2.08646e-12    0.0645259  999.935
#  195 │    97.0    2.06689e-12    0.0613809  999.939
#  196 │    97.5    2.04843e-12    0.0583893  999.942
#  197 │    98.0    2.03102e-12    0.0555434  999.944
#  198 │    98.5    2.01458e-12    0.0528357  999.947
#  199 │    99.0    1.99907e-12    0.0502593  999.95
#  200 │    99.5    1.98442e-12    0.0478081  999.952
#  201 │   100.0    1.97059e-12    0.0454765  999.955
#                                      180 rows omitted

# %% [markdown]
# ## Настройка осей

# %%
x_positions = [1, 2, 3]
labels = ["S", "I", "R"]
# Out:
# 3-element Vector{String}:
#  "S"
#  "I"
#  "R"

# %% [markdown]
# ## Создание анимации

# %%
anim = @animate for i in 1:length(df.time)
# Out:
# ParseError:
# # Error @ ]8;;file://C:/Users/Александра/work/study/2026-1/2026-1==study--simulation-modeling/labs/lab06/project/notebooks/sirpetri_animate_literate/In[6]#1:43\In[6]:1:43]8;;\
# anim = @animate for i in 1:length(df.time)
# #                                         └ ── premature end of input
#
# Stacktrace:
#  [1] top-level scope
#    @ In[6]:1
#  [2] execute_request(socket::ZMQ.Socket, kernel::IJulia.Kernel, msg::IJulia.Msg)
#    @ IJulia C:\Users\Александра\.julia\packages\IJulia\Vl5w1\src\execute_request.jl:129

# %% [markdown]
# Текущие значения

# %%
    S_val = round(Int, df.S[i])
    I_val = round(Int, df.I[i])
    R_val = round(Int, df.R[i])
    t_val = round(df.time[i], digits=1)
# Out:
# UndefVarError: `i` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[7]:1
#  [2] execute_request(socket::ZMQ.Socket, kernel::IJulia.Kernel, msg::IJulia.Msg)
#    @ IJulia C:\Users\Александра\.julia\packages\IJulia\Vl5w1\src\execute_request.jl:129

# %% [markdown]
# График: линия через точки (S, I, R)

# %%
    plot(
        x_positions,
        [S_val, I_val, R_val],
        label = "Population",
        marker = :circle,
        markersize = 8,
        linewidth = 2,
        xlabel = "Compartment",
        ylabel = "Population",
        title = "SIR dynamics at t = $t_val",
        xticks = (x_positions, labels),
        ylims = (0, 1000),
        color = :blue,
    )
end
# Out:
# UndefVarError: `S_val` not defined in `Main`
# Suggestion: add an appropriate import or assignment. This global was declared but not assigned.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[8]:1
#  [2] execute_request(socket::ZMQ.Socket, kernel::IJulia.Kernel, msg::IJulia.Msg)
#    @ IJulia C:\Users\Александра\.julia\packages\IJulia\Vl5w1\src\execute_request.jl:129

# %% [markdown]
# ## Сохранение GIF

# %%
gif_path = plotsdir("sir_animation_line.gif")
gif(anim, gif_path, fps = 10)
# Out:
# UndefVarError: `anim` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[9]:2
#  [2] execute_request(socket::ZMQ.Socket, kernel::IJulia.Kernel, msg::IJulia.Msg)
#    @ IJulia C:\Users\Александра\.julia\packages\IJulia\Vl5w1\src\execute_request.jl:129

# %% [markdown]
# ## Отображение GIF в Jupyter Notebook
#
# Следующая команда показывает сохранённую анимацию прямо в ноутбуке.

# %%
display("text/html", "<img src=\"$(gif_path)\" alt=\"SIR Animation\" style=\"max-width:100%;\">")
# Out:
# <img src="C:\Users\Александра\work\study\2026-1\2026-1==study--simulation-modeling\labs\lab06\project\plots\sir_animation_line.gif" alt="SIR Animation" style="max-width:100%;">

# %% [markdown]
# ## Вывод

# %%
println("Анимация сохранена в $gif_path")
println("На анимации видно:")
println("- S постепенно падает от 990 до почти 0")
println("- I растёт, достигает пика, затем снижается")
println("- R растёт и выходит на плато около 990")
# Out:
# Анимация сохранена в C:\Users\Александра\work\study\2026-1\2026-1==study--simulation-modeling\labs\lab06\project\plots\sir_animation_line.gif
# На анимации видно:
# - S постепенно падает от 990 до почти 0
# - I растёт, достигает пика, затем снижается
# - R растёт и выходит на плато около 990
